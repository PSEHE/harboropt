# %% [markdown]
# # Simple Linear Program
#
# A simple linear program with only 2 variables and 3 constraints in order to learn the API of the OR Tools linear solver.

# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np # numerical library
import matplotlib.pyplot as plt # plotting library
import utils
import datetime as dt
import pandas as pd

from ortools.linear_solver import pywraplp

# %%
# this is the "solver" which does the actual work of solving the linear program
solver = pywraplp.Solver('HarborOptimization',
                         pywraplp.Solver.GLOP_LINEAR_PROGRAMMING)

# %%
# declare variables
x = solver.NumVar(0, solver.infinity(), 'x')
y = solver.NumVar(0, solver.infinity(), 'y')

# %%
# Constraint 0: x + 2y <= 14.
constraint0 = solver.Constraint(-solver.infinity(), 14)
constraint0.SetCoefficient(x, 1)
constraint0.SetCoefficient(y, 2)

# Constraint 1: 3x - y >= 0.
constraint1 = solver.Constraint(0, solver.infinity())
constraint1.SetCoefficient(x, 3)
constraint1.SetCoefficient(y, -1)

# Constraint 2: x - y <= 2.
constraint2 = solver.Constraint(-solver.infinity(), 2)
constraint2.SetCoefficient(x, 1)
constraint2.SetCoefficient(y, -1)

# %%
# Objective function: 3x + 4y.
objective = solver.Objective()
objective.SetCoefficient(x, 3)
objective.SetCoefficient(y, 4)
objective.SetMaximization()

# %%
solver.Solve()
# Out:
# 0

# %%
opt_solution = 3 * x.solution_value() + 4 * y.solution_value()
print('Number of variables =', solver.NumVariables())
print('Number of constraints =', solver.NumConstraints())
# The value of each variable in the solution.
print('Solution:')
print('x = ', x.solution_value())
print('y = ', y.solution_value())
# The objective value of the solution.
print('Optimal objective value =', opt_solution)
# Out:
# Number of variables = 2
# Number of constraints = 3
# Solution:
# x =  5.999999999999998
# y =  3.9999999999999996
# Optimal objective value = 33.99999999999999

# %%
objective.Value()
# Out:
# 33.99999999999999

# %% [markdown]
# ## Timepoints as Variables
#
# Now that we are familiar with how to set up the variables, constraints, and optimization for a linear program, we write a slightly more complicated linear program that uses *lists* of variables that represent time points.
#
# Translate the following linear program in code:
#
# $$
# max_{h_1, \ldots, h_{24}} \sum_{i=1}^{24} h_i
# \\
# \text{s.t.}~h_i \leq 5~\forall i~\text{and} ~h_5 \leq2
# $$

# %%
timesolver = pywraplp.Solver('HarborOptimization',
                         pywraplp.Solver.GLOP_LINEAR_PROGRAMMING)

all_hours = []
objective = timesolver.Objective()

for i in range(24):
    h = timesolver.NumVar(-timesolver.infinity(), 5, 'h'+ str(i)) 
    if i == 4:
        h = timesolver.NumVar(-timesolver.infinity(), 2, 'h'+ str(i)) 
    objective.SetCoefficient(h, 1)
    all_hours.append(h)

objective.SetMaximization()
timesolver.Solve()
print(objective.Value())
# Out:
# 117.0

# %%
for i in range(24):
    print(all_hours[i].solution_value())
# Out:
# 5.0
# 5.0
# 5.0
# 5.0
# 2.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0

# %% [markdown]
# ## Simple linear program with two resources
#
# Using the basic structure of the examples above, we write a linear program that cost-optimizes a portfolio of natural gas and solar resources to match Harbor's historic generation profile.

# %%
#Load Harbor historical hourly generation and emissions for 2014-2018. Group by datetime to sum generation and emissions from all units. Filter for specific year -- make sure selected year isn't leap year.
harborgen = utils.get_harbor_data('data/HarborHourly_2014-18.csv')
harborgen = harborgen.groupby(['datetime'])['kwh', 'SO2_MASS..lbs.', 'NOX_MASS..lbs.', 'CO2_MASS..tons.'].sum()

# Create string object that is the chosen year
year = '2018'

# Filter Harbor data by the chosen year, using the string object above.
harborgen.filter(like=year, axis=0)

# Load solar generation profile for 1 KW system. Change all years in solar dataset to match year chosen above. Set datetime as index.
solargen = utils.get_solar_data()
solargen['datetime'] = solargen['datetime'].mask(solargen['datetime'].dt.year == 1900, solargen['datetime'] + pd.offsets.DateOffset(year=int(year)))
solargen.set_index(['datetime'], inplace=True, drop=True)
# Out:
# /Users/AnnieDillon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/AnnieDillon/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:692: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   PerformanceWarning,

# %%
solargen.head()
# Out:
#                      kwh
# datetime
# 2018-01-01 00:00:00  0.0
# 2018-01-01 01:00:00  0.0
# 2018-01-01 02:00:00  0.0
# 2018-01-01 03:00:00  0.0
# 2018-01-01 04:00:00  0.0

# %%
harborgen.head()
# Out:
#                      kwh  SO2_MASS..lbs.  NOX_MASS..lbs.  CO2_MASS..tons.
# datetime
# 2014-01-01 00:00:00  0.0             0.0             0.0              0.0
# 2014-01-01 01:00:00  0.0             0.0             0.0              0.0
# 2014-01-01 02:00:00  0.0             0.0             0.0              0.0
# 2014-01-01 03:00:00  0.0             0.0             0.0              0.0
# 2014-01-01 04:00:00  0.0             0.0             0.0              0.0

# %%
solargas_solver = pywraplp.Solver('HarborOptimization',
                         pywraplp.Solver.GLOP_LINEAR_PROGRAMMING)

# Declare solar and gas nameplate capacity variables.
s_kw = solargas_solver.NumVar(0, solargas_solver.infinity(), 's_kw')
g_kw = solargas_solver.NumVar(0, solargas_solver.infinity(), 'g_kw')

# %%
#Keep track of gas generation variable for every hour.
gas_hourly_gen = []

#Introduce objective object so we can refer to it in the for loop.
objective = solargas_solver.Objective()

#Loop through every hour, creating hourly constraints. **Change to datetime index.
for ind in harborgen.index:
    gen = solargas_solver.NumVar(0, solargas_solver.infinity(), 'gen'+ str(ind))
    gas_hourly_gen.append(gen)
    
    #Summed solar and gas generation must be equal or greater to demand in all hours.
    constraint1 = solargas_solver.Constraint(harborgen.loc[ind,'kwh'], solargas_solver.infinity())
    constraint1.SetCoefficient(s_kw, solargen.loc[ind,'kwh'])
    constraint1.SetCoefficient(gen, 1)
    
    #Gas generation must be less than or equal to gas capacity in all hours.
    constraint2 = solargas_solver.Constraint(0, solargas_solver.infinity())
    constraint2.SetCoefficient(g_kw, 1)
    constraint2.SetCoefficient(gen, -1)
   
    # Add cost here for gas variable generation ($/kwh)
    objective.SetCoefficient(gen, .021)

# %%
## Add in numbers here for capital and fixed costs -- for fixed, we need to assume a certain plant lifetime and amortize over that period. ******

objective.SetCoefficient(s_kw, 630)
objective.SetCoefficient(g_kw, 672)

objective.SetMinimization()
solargas_solver.Solve()
print("total cost =", objective.Value())

#Sums gas generation for every hour. Prints gas generation for every hour that it is > 0.
summed_gas_gen = 0
for i in range(8760):
    summed_gas_gen = summed_gas_gen + gas_hourly_gen[i].solution_value()
    if gas_hourly_gen[i].solution_value() > 0.0:
        print("gas generation at hour", str(i), gas_hourly_gen[i].solution_value())

print("annual gas generation (kwh) =", summed_gas_gen)
print("solar nameplate capacity (kw) =", s_kw.solution_value())
print("gas nameplate capacity (kw) =", g_kw.solution_value())
# Out:
# total cost = 232972157.88
# gas generation at hour 55 6840.0
# gas generation at hour 58 22319.999999999996
# gas generation at hour 59 17999.999999999996
# gas generation at hour 62 2430.0
# gas generation at hour 63 64679.999999999985
# gas generation at hour 64 8640.0
# gas generation at hour 103 6460.0
# gas generation at hour 104 62719.999999999985
# gas generation at hour 105 16379.999999999998
# gas generation at hour 175 15400.000000000002
# gas generation at hour 176 7920.000000000001
# gas generation at hour 177 8320.0
# gas generation at hour 178 12000.0
# gas generation at hour 179 340.00000000000006
# gas generation at hour 199 10829.999999999998
# gas generation at hour 200 11999.999999999998
# gas generation at hour 201 169.99999999999997
# gas generation at hour 202 16799.999999999996
# gas generation at hour 203 8370.0
# gas generation at hour 223 5600.0
# gas generation at hour 224 42750.0
# gas generation at hour 225 41650.0
# gas generation at hour 226 22440.0
# gas generation at hour 227 14040.000000000004
# gas generation at hour 228 38250.0
# gas generation at hour 247 5850.000000000001
# gas generation at hour 248 20000.0
# gas generation at hour 249 14999.999999999998
# gas generation at hour 391 9030.0
# gas generation at hour 392 35000.0
# gas generation at hour 393 15370.000000000002
# gas generation at hour 394 49980.00000000001
# gas generation at hour 435 33750.0
# gas generation at hour 436 81000.0
# gas generation at hour 437 175000.0
# gas generation at hour 438 212000.0
# gas generation at hour 439 219000.0
# gas generation at hour 440 219000.0
# gas generation at hour 441 219000.0
# gas generation at hour 442 198350.0
# gas generation at hour 443 2449.9999999999995
# gas generation at hour 468 9010.000000000002
# gas generation at hour 469 47000.0
# gas generation at hour 470 47000.0
# gas generation at hour 471 47000.0
# gas generation at hour 472 150.0
# gas generation at hour 559 340.00000000000006
# gas generation at hour 560 68600.0
# gas generation at hour 561 14369.999999999998
# gas generation at hour 562 62720.0
# gas generation at hour 565 24480.0
# gas generation at hour 566 40020.00000000001
# gas generation at hour 728 7600.0
# gas generation at hour 729 66640.0
# gas generation at hour 730 13200.0
# gas generation at hour 731 10350.0
# gas generation at hour 732 67000.0
# gas generation at hour 733 19430.000000000004
# gas generation at hour 848 4920.0
# gas generation at hour 849 93999.99999999999
# gas generation at hour 850 94000.0
# gas generation at hour 851 49399.99999999999
# gas generation at hour 852 47000.0
# gas generation at hour 853 46999.99999999999
# gas generation at hour 854 47000.0
# gas generation at hour 855 47000.0
# gas generation at hour 856 47000.0
# gas generation at hour 857 17680.0
# gas generation at hour 871 7800.000000000001
# gas generation at hour 872 40000.0
# gas generation at hour 873 40000.0
# gas generation at hour 874 40000.00000000001
# gas generation at hour 875 39999.99999999999
# gas generation at hour 876 40000.0
# gas generation at hour 877 40000.0
# gas generation at hour 878 40000.0
# gas generation at hour 879 39999.99999999999
# gas generation at hour 880 40000.0
# gas generation at hour 881 3330.0
# gas generation at hour 896 44000.0
# gas generation at hour 897 65239.999999999985
# gas generation at hour 898 105800.0
# gas generation at hour 899 51720.00000000001
# gas generation at hour 900 110000.0
# gas generation at hour 901 52550.0
# gas generation at hour 902 47000.0
# gas generation at hour 903 42000.00000000001
# gas generation at hour 919 9860.0
# gas generation at hour 920 40000.00000000001
# gas generation at hour 921 40000.0
# gas generation at hour 922 40000.0
# gas generation at hour 923 40000.0
# gas generation at hour 924 40000.0
# gas generation at hour 925 40000.0
# gas generation at hour 926 40000.0
# gas generation at hour 927 40000.0
# gas generation at hour 928 30400.0
# gas generation at hour 1063 4620.0
# gas generation at hour 1064 36400.0
# gas generation at hour 1065 9030.0
# gas generation at hour 1066 51940.0
# gas generation at hour 1067 49999.99999999999
# gas generation at hour 1068 2250.0000000000005
# gas generation at hour 1087 1920.0
# gas generation at hour 1088 20000.0
# gas generation at hour 1089 250.0
# gas generation at hour 1258 15680.0
# gas generation at hour 1259 1920.0
# gas generation at hour 1352 10790.000000000004
# gas generation at hour 1353 73149.99999999999
# gas generation at hour 1354 85000.0
# gas generation at hour 1355 99999.99999999997
# gas generation at hour 1356 100000.00000000001
# gas generation at hour 1357 100000.00000000001
# gas generation at hour 1358 99999.99999999997
# gas generation at hour 1359 100000.00000000001
# gas generation at hour 1360 101000.00000000001
# gas generation at hour 1361 99999.99999999999
# gas generation at hour 1362 16560.0
# gas generation at hour 1373 9870.0
# gas generation at hour 1374 82000.0
# gas generation at hour 1375 104000.00000000003
# gas generation at hour 1376 110000.0
# gas generation at hour 1377 110000.0
# gas generation at hour 1378 110000.00000000001
# gas generation at hour 1379 110000.0
# gas generation at hour 1380 110000.00000000001
# gas generation at hour 1381 110000.0
# gas generation at hour 1382 110000.00000000001
# gas generation at hour 1383 102000.0
# gas generation at hour 1384 4360.0
# gas generation at hour 1385 9540.000000000002
# gas generation at hour 1401 20000.000000000004
# gas generation at hour 1402 2500.0
# gas generation at hour 1432 8320.0
# gas generation at hour 1433 360.00000000000006
# gas generation at hour 1568 339.99999999999994
# gas generation at hour 1569 76000.0
# gas generation at hour 1570 41800.00000000001
# gas generation at hour 1572 65000.0
# gas generation at hour 1573 39559.999999999985
# gas generation at hour 1615 4729.999999999999
# gas generation at hour 1616 17000.000000000004
# gas generation at hour 1617 540.0000000000001
# gas generation at hour 1684 43000.0
# gas generation at hour 1685 47000.0
# gas generation at hour 1686 47000.0
# gas generation at hour 1687 17600.0
# gas generation at hour 1688 47000.0
# gas generation at hour 1689 47000.0
# gas generation at hour 1690 46999.99999999999
# gas generation at hour 1691 46000.00000000001
# gas generation at hour 1692 45179.999999999985
# gas generation at hour 1693 85000.0
# gas generation at hour 1694 86000.0
# gas generation at hour 1695 87000.0
# gas generation at hour 1696 88000.0
# gas generation at hour 1697 89000.00000000001
# gas generation at hour 1698 89000.0
# gas generation at hour 1699 89000.0
# gas generation at hour 1700 89000.0
# gas generation at hour 1701 89000.0
# gas generation at hour 1702 4710.0
# gas generation at hour 1713 3510.0
# gas generation at hour 1714 90000.0
# gas generation at hour 1715 93499.99999999999
# gas generation at hour 1716 126000.00000000003
# gas generation at hour 1717 123000.00000000001
# gas generation at hour 1718 122000.0
# gas generation at hour 1719 42710.0
# gas generation at hour 1720 40000.00000000001
# gas generation at hour 1721 40000.00000000001
# gas generation at hour 1722 40000.0
# gas generation at hour 1723 16750.0
# gas generation at hour 1734 3800.0
# gas generation at hour 1735 41000.0
# gas generation at hour 1736 39999.99999999999
# gas generation at hour 1737 40000.0
# gas generation at hour 1738 40000.0
# gas generation at hour 1739 39999.99999999999
# gas generation at hour 1740 40000.0
# gas generation at hour 1741 40000.0
# gas generation at hour 1742 39999.99999999999
# gas generation at hour 1743 40000.0
# gas generation at hour 1744 82000.0
# gas generation at hour 1745 62559.99999999999
# gas generation at hour 1858 16940.0
# gas generation at hour 1859 9000.0
# gas generation at hour 1904 6459.999999999999
# gas generation at hour 1905 61740.0
# gas generation at hour 1906 6400.0
# gas generation at hour 1907 21579.999999999993
# gas generation at hour 1908 49980.00000000001
# gas generation at hour 1909 390.0
# gas generation at hour 2023 21000.000000000004
# gas generation at hour 2024 7680.0
# gas generation at hour 2027 470.00000000000006
# gas generation at hour 2028 1500.0
# gas generation at hour 2046 7199.999999999999
# gas generation at hour 2047 14000.0
# gas generation at hour 2048 16940.0
# gas generation at hour 2049 1160.0
# gas generation at hour 2052 2120.0
# gas generation at hour 2053 1349.9999999999998
# gas generation at hour 2082 7199.999999999999
# gas generation at hour 2083 300.00000000000006
# gas generation at hour 2120 899.9999999999999
# gas generation at hour 2121 47000.0
# gas generation at hour 2122 47000.00000000001
# gas generation at hour 2123 1620.0
# gas generation at hour 2235 10350.0
# gas generation at hour 2236 77000.0
# gas generation at hour 2237 87290.0
# gas generation at hour 2238 199000.00000000003
# gas generation at hour 2239 224000.0
# gas generation at hour 2240 224000.00000000003
# gas generation at hour 2241 182549.99999999994
# gas generation at hour 2242 57999.99999999999
# gas generation at hour 2243 4290.0
# gas generation at hour 2364 340.00000000000006
# gas generation at hour 2365 73000.00000000001
# gas generation at hour 2366 99379.99999999999
# gas generation at hour 2367 193999.99999999997
# gas generation at hour 2368 212000.0
# gas generation at hour 2369 215000.0
# gas generation at hour 2370 216000.0
# gas generation at hour 2371 212000.0
# gas generation at hour 2372 10610.0
# gas generation at hour 2389 12000.0
# gas generation at hour 2390 109089.99999999999
# gas generation at hour 2391 203000.0
# gas generation at hour 2392 215999.99999999997
# gas generation at hour 2393 215999.99999999997
# gas generation at hour 2394 216000.0
# gas generation at hour 2395 216000.0
# gas generation at hour 2396 216000.0
# gas generation at hour 2397 158250.0
# gas generation at hour 2398 1060.0
# gas generation at hour 2529 17500.0
# gas generation at hour 2530 9800.0
# gas generation at hour 2547 130.0
# gas generation at hour 2548 79000.0
# gas generation at hour 2549 92000.0
# gas generation at hour 2550 112000.0
# gas generation at hour 2551 112999.99999999997
# gas generation at hour 2552 112999.99999999999
# gas generation at hour 2553 112000.0
# gas generation at hour 2554 112000.00000000001
# gas generation at hour 2555 111000.0
# gas generation at hour 2556 110000.0
# gas generation at hour 2557 110000.0
# gas generation at hour 2558 111000.0
# gas generation at hour 2559 124020.0
# gas generation at hour 2560 156999.99999999997
# gas generation at hour 2561 33550.0
# gas generation at hour 2573 5850.000000000001
# gas generation at hour 2574 40800.0
# gas generation at hour 2575 102720.00000000001
# gas generation at hour 2576 43300.0
# gas generation at hour 2577 40000.0
# gas generation at hour 2578 40000.0
# gas generation at hour 2579 40000.0
# gas generation at hour 2580 40000.0
# gas generation at hour 2581 40000.0
# gas generation at hour 2582 40000.0
# gas generation at hour 2583 35000.0
# gas generation at hour 2597 13230.0
# gas generation at hour 2598 40000.0
# gas generation at hour 2599 40000.0
# gas generation at hour 2600 39999.99999999999
# gas generation at hour 2601 40000.0
# gas generation at hour 2602 40000.0
# gas generation at hour 2603 40000.0
# gas generation at hour 2604 40000.0
# gas generation at hour 2605 40000.0
# gas generation at hour 2606 40000.0
# gas generation at hour 2607 33320.0
# gas generation at hour 2701 3080.0
# gas generation at hour 2702 75000.0
# gas generation at hour 2703 86000.0
# gas generation at hour 2704 107000.0
# gas generation at hour 2705 107000.0
# gas generation at hour 2706 108000.00000000003
# gas generation at hour 2707 108000.0
# gas generation at hour 2708 109000.0
# gas generation at hour 2709 27000.0
# gas generation at hour 2719 18480.0
# gas generation at hour 2720 12000.000000000002
# gas generation at hour 2731 74100.0
# gas generation at hour 2732 27040.0
# gas generation at hour 2745 12600.000000000002
# gas generation at hour 2746 10000.000000000002
# gas generation at hour 2791 7500.000000000001
# gas generation at hour 2792 13000.0
# gas generation at hour 2793 690.0000000000001
# gas generation at hour 2886 4000.0
# gas generation at hour 2887 13200.0
# gas generation at hour 2889 21000.000000000004
# gas generation at hour 2891 2999.9999999999995
# gas generation at hour 2892 2400.0
# gas generation at hour 2907 540.0
# gas generation at hour 2908 76000.0
# gas generation at hour 2909 87999.99999999999
# gas generation at hour 2910 107000.0
# gas generation at hour 2911 109000.00000000001
# gas generation at hour 2912 108000.00000000001
# gas generation at hour 2913 107000.0
# gas generation at hour 2914 107000.0
# gas generation at hour 2915 106999.99999999997
# gas generation at hour 2916 107000.00000000003
# gas generation at hour 2917 107000.0
# gas generation at hour 2918 106999.99999999999
# gas generation at hour 2919 107000.0
# gas generation at hour 2920 107000.0
# gas generation at hour 2921 107999.99999999999
# gas generation at hour 2922 171000.0
# gas generation at hour 2923 212000.0
# gas generation at hour 2924 216000.0
# gas generation at hour 2925 38240.0
# gas generation at hour 3064 44000.0
# gas generation at hour 3065 47000.0
# gas generation at hour 3066 2970.0000000000005
# gas generation at hour 3246 8400.0
# gas generation at hour 3247 66000.0
# gas generation at hour 3248 8929.999999999998
# gas generation at hour 3326 6460.0
# gas generation at hour 3327 75000.0
# gas generation at hour 3328 102150.0
# gas generation at hour 3329 181000.0
# gas generation at hour 3330 204999.99999999997
# gas generation at hour 3331 195000.0
# gas generation at hour 3332 6000.0
# gas generation at hour 3390 8320.0
# gas generation at hour 3391 18000.0
# gas generation at hour 3392 13129.999999999996
# gas generation at hour 3393 3420.000000000001
# gas generation at hour 3414 400.0
# gas generation at hour 3415 25000.000000000004
# gas generation at hour 3416 990.0
# gas generation at hour 3582 2520.0000000000005
# gas generation at hour 3583 66000.0
# gas generation at hour 3584 5549.999999999999
# gas generation at hour 3922 7560.000000000001
# gas generation at hour 3923 63999.99999999999
# gas generation at hour 3924 15079.999999999996
# gas generation at hour 4086 10440.0
# gas generation at hour 4087 7440.000000000001
# gas generation at hour 4088 8840.0
# gas generation at hour 4089 10670.0
# gas generation at hour 4109 22050.0
# gas generation at hour 4110 77000.0
# gas generation at hour 4111 92000.00000000001
# gas generation at hour 4112 102000.00000000001
# gas generation at hour 4113 103000.0
# gas generation at hour 4114 103000.0
# gas generation at hour 4115 102000.0
# gas generation at hour 4116 59519.99999999999
# gas generation at hour 4122 45760.0
# gas generation at hour 4133 22310.0
# gas generation at hour 4134 6080.0
# gas generation at hour 4135 18000.000000000004
# gas generation at hour 4256 45239.99999999999
# gas generation at hour 4257 36540.0
# gas generation at hour 4283 22330.000000000004
# gas generation at hour 4284 8550.000000000002
# gas generation at hour 4381 63000.000000000015
# gas generation at hour 4382 26650.0
# gas generation at hour 4500 33540.0
# gas generation at hour 4501 74510.00000000001
# gas generation at hour 4502 171000.0
# gas generation at hour 4503 203000.00000000003
# gas generation at hour 4504 205000.0
# gas generation at hour 4505 204999.99999999997
# gas generation at hour 4506 207000.00000000003
# gas generation at hour 4507 179600.0
# gas generation at hour 4508 4560.000000000001
# gas generation at hour 4589 130.0
# gas generation at hour 4590 63699.99999999999
# gas generation at hour 4591 38640.00000000001
# gas generation at hour 4593 29930.0
# gas generation at hour 4594 35670.00000000001
# gas generation at hour 4739 7200.000000000001
# gas generation at hour 4740 82520.0
# gas generation at hour 4741 86200.0
# gas generation at hour 4742 100000.00000000001
# gas generation at hour 4743 101000.0
# gas generation at hour 4744 102000.0
# gas generation at hour 4745 102000.0
# gas generation at hour 4746 6110.0
# gas generation at hour 4759 68800.00000000001
# gas generation at hour 4760 130580.0
# gas generation at hour 4761 101000.00000000003
# gas generation at hour 4762 100000.00000000003
# gas generation at hour 4763 99999.99999999999
# gas generation at hour 4764 98999.99999999999
# gas generation at hour 4765 99000.0
# gas generation at hour 4766 99000.0
# gas generation at hour 4767 176000.0
# gas generation at hour 4768 208000.0
# gas generation at hour 4769 209999.99999999997
# gas generation at hour 4770 210000.0
# gas generation at hour 4771 210000.0
# gas generation at hour 4772 93240.0
# gas generation at hour 4806 30000.0
# gas generation at hour 4807 5739.999999999998
# gas generation at hour 4883 46800.0
# gas generation at hour 4884 75540.0
# gas generation at hour 4885 166000.0
# gas generation at hour 4886 202000.0
# gas generation at hour 4887 206999.99999999997
# gas generation at hour 4888 205999.99999999997
# gas generation at hour 4889 206000.0
# gas generation at hour 4890 206000.00000000003
# gas generation at hour 4891 207000.0
# gas generation at hour 4892 207000.0
# gas generation at hour 4893 207000.0
# gas generation at hour 4894 58959.99999999999
# gas generation at hour 4902 22500.0
# gas generation at hour 4906 68000.0
# gas generation at hour 4907 163499.99999999997
# gas generation at hour 4908 219430.00000000006
# gas generation at hour 4909 202000.00000000003
# gas generation at hour 4910 202000.00000000003
# gas generation at hour 4911 203000.0
# gas generation at hour 4912 202999.99999999997
# gas generation at hour 4913 204000.0
# gas generation at hour 4914 204000.0
# gas generation at hour 4915 205000.0
# gas generation at hour 4916 205000.0
# gas generation at hour 4917 192000.0
# gas generation at hour 4918 12870.0
# gas generation at hour 4926 6080.0
# gas generation at hour 4927 73999.99999999999
# gas generation at hour 4928 83900.0
# gas generation at hour 4929 183999.99999999997
# gas generation at hour 4930 202999.99999999997
# gas generation at hour 4931 204000.00000000003
# gas generation at hour 4932 203000.0
# gas generation at hour 4933 201000.0
# gas generation at hour 4934 201000.0
# gas generation at hour 4935 201000.0
# gas generation at hour 4936 201000.0
# gas generation at hour 4937 201000.0
# gas generation at hour 4938 204000.0
# gas generation at hour 4939 205000.0
# gas generation at hour 4940 206000.0
# gas generation at hour 4941 176000.0
# gas generation at hour 4942 9470.0
# gas generation at hour 4952 5850.000000000001
# gas generation at hour 4953 15000.000000000002
# gas generation at hour 4954 180.0
# gas generation at hour 5045 24000.0
# gas generation at hour 5046 47000.0
# gas generation at hour 5047 47000.00000000001
# gas generation at hour 5048 47000.00000000001
# gas generation at hour 5049 46999.99999999999
# gas generation at hour 5050 47000.0
# gas generation at hour 5051 107000.0
# gas generation at hour 5052 127000.0
# gas generation at hour 5053 203870.0
# gas generation at hour 5054 250989.99999999997
# gas generation at hour 5055 344000.00000000006
# gas generation at hour 5056 344999.99999999994
# gas generation at hour 5057 245340.00000000003
# gas generation at hour 5058 187000.0
# gas generation at hour 5059 15759.999999999998
# gas generation at hour 5069 9010.0
# gas generation at hour 5070 47000.0
# gas generation at hour 5071 47000.00000000001
# gas generation at hour 5072 47000.0
# gas generation at hour 5073 47000.0
# gas generation at hour 5074 46999.99999999999
# gas generation at hour 5075 46999.99999999999
# gas generation at hour 5076 47000.00000000001
# gas generation at hour 5077 15600.000000000002
# gas generation at hour 5093 20250.0
# gas generation at hour 5094 47000.0
# gas generation at hour 5095 47000.0
# gas generation at hour 5096 47000.0
# gas generation at hour 5097 47000.0
# gas generation at hour 5098 47000.00000000001
# gas generation at hour 5099 35339.99999999999
# gas generation at hour 5104 13860.0
# gas generation at hour 5105 47000.0
# gas generation at hour 5106 45999.99999999999
# gas generation at hour 5107 1620.0
# gas generation at hour 5118 40000.0
# gas generation at hour 5119 46000.00000000001
# gas generation at hour 5120 47000.0
# gas generation at hour 5121 47000.00000000001
# gas generation at hour 5122 47000.0
# gas generation at hour 5123 47000.0
# gas generation at hour 5124 10799.999999999998
# gas generation at hour 5141 16320.0
# gas generation at hour 5142 47000.0
# gas generation at hour 5143 47000.0
# gas generation at hour 5144 47000.0
# gas generation at hour 5145 46000.00000000001
# gas generation at hour 5146 46999.99999999999
# gas generation at hour 5147 28899.999999999996
# gas generation at hour 5242 25900.0
# gas generation at hour 5243 74000.0
# gas generation at hour 5244 163999.99999999997
# gas generation at hour 5245 199000.0
# gas generation at hour 5246 202000.00000000003
# gas generation at hour 5247 202000.0
# gas generation at hour 5248 204000.0
# gas generation at hour 5249 204000.0
# gas generation at hour 5250 204999.99999999997
# gas generation at hour 5251 205000.0
# gas generation at hour 5252 205000.0
# gas generation at hour 5253 71400.0
# gas generation at hour 5267 97880.00000000001
# gas generation at hour 5268 192000.0
# gas generation at hour 5269 204000.0
# gas generation at hour 5270 204000.0
# gas generation at hour 5271 204000.00000000003
# gas generation at hour 5272 203000.0
# gas generation at hour 5273 204000.00000000003
# gas generation at hour 5274 205000.0
# gas generation at hour 5275 200000.0
# gas generation at hour 5276 6400.0
# gas generation at hour 5290 89949.99999999999
# gas generation at hour 5291 177000.00000000003
# gas generation at hour 5292 201000.0
# gas generation at hour 5293 200000.00000000003
# gas generation at hour 5294 199999.99999999997
# gas generation at hour 5295 201999.99999999994
# gas generation at hour 5296 203000.0
# gas generation at hour 5297 205000.0
# gas generation at hour 5298 204999.99999999997
# gas generation at hour 5299 207000.0
# gas generation at hour 5300 207000.0
# gas generation at hour 5301 166000.0
# gas generation at hour 5302 12240.0
# gas generation at hour 5408 1150.0000000000002
# gas generation at hour 5409 72000.00000000001
# gas generation at hour 5410 109400.00000000001
# gas generation at hour 5411 191000.00000000003
# gas generation at hour 5412 206000.00000000003
# gas generation at hour 5413 207000.00000000003
# gas generation at hour 5414 206000.0
# gas generation at hour 5415 205000.00000000006
# gas generation at hour 5416 206000.0
# gas generation at hour 5417 206000.00000000003
# gas generation at hour 5418 208000.0
# gas generation at hour 5419 208000.0
# gas generation at hour 5420 129840.0
# gas generation at hour 5435 16259.999999999996
# gas generation at hour 5436 157999.99999999997
# gas generation at hour 5437 186000.0
# gas generation at hour 5438 204000.0
# gas generation at hour 5439 205000.0
# gas generation at hour 5440 37289.99999999999
# gas generation at hour 5454 11160.0
# gas generation at hour 5455 40000.0
# gas generation at hour 5456 40000.0
# gas generation at hour 5457 40000.00000000001
# gas generation at hour 5458 40000.0
# gas generation at hour 5459 40000.0
# gas generation at hour 5460 40000.0
# gas generation at hour 5461 40000.0
# gas generation at hour 5462 40000.0
# gas generation at hour 5463 40000.0
# gas generation at hour 5464 1750.0
# gas generation at hour 5477 1500.0
# gas generation at hour 5478 40000.0
# gas generation at hour 5479 40000.0
# gas generation at hour 5480 40000.0
# gas generation at hour 5481 40000.0
# gas generation at hour 5482 40000.0
# gas generation at hour 5483 40000.0
# gas generation at hour 5484 39999.99999999999
# gas generation at hour 5485 40000.0
# gas generation at hour 5486 40000.0
# gas generation at hour 5487 35890.0
# gas generation at hour 5550 440.0
# gas generation at hour 5551 24000.0
# gas generation at hour 5552 6300.000000000001
# gas generation at hour 5553 18999.999999999996
# gas generation at hour 5576 13230.000000000002
# gas generation at hour 5577 5950.0
# gas generation at hour 5578 19140.0
# gas generation at hour 5579 14960.000000000002
# gas generation at hour 5599 56259.99999999999
# gas generation at hour 5600 40500.00000000001
# gas generation at hour 5624 16170.0
# gas generation at hour 5625 3900.000000000001
# gas generation at hour 5934 800.0
# gas generation at hour 5935 73000.0
# gas generation at hour 5936 54879.99999999999
# gas generation at hour 5937 3620.0
# gas generation at hour 5938 61740.00000000001
# gas generation at hour 5939 10079.999999999996
# gas generation at hour 6053 22680.0
# gas generation at hour 6054 75000.0
# gas generation at hour 6055 93000.0
# gas generation at hour 6056 99999.99999999999
# gas generation at hour 6057 99000.0
# gas generation at hour 6058 174000.0
# gas generation at hour 6059 205000.0
# gas generation at hour 6060 206000.0
# gas generation at hour 6061 204000.0
# gas generation at hour 6062 202999.99999999997
# gas generation at hour 6063 202000.0
# gas generation at hour 6064 203000.0
# gas generation at hour 6065 205000.0
# gas generation at hour 6066 207000.0
# gas generation at hour 6067 208000.0
# gas generation at hour 6068 209000.0
# gas generation at hour 6069 209000.0
# gas generation at hour 6070 57960.0
# gas generation at hour 6103 749.9999999999999
# gas generation at hour 6104 23400.000000000004
# gas generation at hour 6106 4160.0
# gas generation at hour 6274 1320.0
# gas generation at hour 6275 58800.00000000001
# gas generation at hour 6276 4899.999999999999
# gas generation at hour 6318 800.0
# gas generation at hour 6319 70000.0
# gas generation at hour 6320 20770.0
# gas generation at hour 6321 19399.999999999996
# gas generation at hour 6322 9820.0
# gas generation at hour 6323 13000.0
# gas generation at hour 6438 17520.0
# gas generation at hour 6439 7440.000000000001
# gas generation at hour 6440 21160.0
# gas generation at hour 6441 2900.0
# gas generation at hour 6606 58800.0
# gas generation at hour 6607 1140.0
# gas generation at hour 6608 11249.999999999998
# gas generation at hour 6609 59779.999999999985
# gas generation at hour 6610 18850.0
# gas generation at hour 6750 13230.000000000002
# gas generation at hour 6751 17000.0
# gas generation at hour 6752 1349.9999999999998
# gas generation at hour 6753 28000.0
# gas generation at hour 6754 3000.0
# gas generation at hour 6774 5850.000000000001
# gas generation at hour 6775 14000.0
# gas generation at hour 6776 200.0
# gas generation at hour 6799 18600.0
# gas generation at hour 6800 10000.0
# gas generation at hour 6809 1680.0
# gas generation at hour 6810 460.0
# gas generation at hour 6946 31390.0
# gas generation at hour 6947 25200.000000000004
# gas generation at hour 6948 59779.99999999999
# gas generation at hour 6949 36540.0
# gas generation at hour 6950 9900.000000000002
# gas generation at hour 6951 8800.0
# gas generation at hour 7278 540.0
# gas generation at hour 7279 66999.99999999999
# gas generation at hour 7280 11959.999999999998
# gas generation at hour 7284 43350.000000000015
# gas generation at hour 7285 52920.00000000001
# gas generation at hour 7286 3080.0
# gas generation at hour 7424 21000.000000000004
# gas generation at hour 7425 11160.0
# gas generation at hour 7426 4900.0
# gas generation at hour 7447 6109.999999999998
# gas generation at hour 7448 15000.0
# gas generation at hour 7449 19000.000000000004
# gas generation at hour 7450 1680.0
# gas generation at hour 7471 7000.0
# gas generation at hour 7472 16000.000000000002
# gas generation at hour 7597 39200.0
# gas generation at hour 7598 78999.99999999999
# gas generation at hour 7599 147400.0
# gas generation at hour 7600 219000.0
# gas generation at hour 7601 225000.0
# gas generation at hour 7602 224000.0
# gas generation at hour 7603 154000.0
# gas generation at hour 7604 1200.0
# gas generation at hour 7616 68000.0
# gas generation at hour 7617 29600.0
# gas generation at hour 7758 30959.999999999996
# gas generation at hour 7759 82000.00000000003
# gas generation at hour 7760 176000.0
# gas generation at hour 7761 217000.0
# gas generation at hour 7762 215999.99999999997
# gas generation at hour 7763 215000.0
# gas generation at hour 7764 214000.0
# gas generation at hour 7765 213000.00000000003
# gas generation at hour 7766 212000.0
# gas generation at hour 7767 214000.0
# gas generation at hour 7768 215999.99999999997
# gas generation at hour 7769 218000.0
# gas generation at hour 7770 217000.0
# gas generation at hour 7771 217000.0
# gas generation at hour 7772 216000.0
# gas generation at hour 7773 123960.0
# gas generation at hour 7774 65700.0
# gas generation at hour 8094 1680.0000000000002
# gas generation at hour 8095 22000.0
# gas generation at hour 8096 14549.999999999998
# gas generation at hour 8097 8370.0
# gas generation at hour 8142 9010.0
# gas generation at hour 8143 15000.000000000002
# gas generation at hour 8144 169.99999999999997
# gas generation at hour 8313 24000.0
# gas generation at hour 8314 9570.000000000002
# gas generation at hour 8315 20369.999999999996
# gas generation at hour 8316 960.0
# gas generation at hour 8436 20790.0
# gas generation at hour 8437 47000.0
# gas generation at hour 8438 47000.00000000001
# gas generation at hour 8439 23100.000000000004
# annual gas generation (kwh) = 53912280.0
# solar nameplate capacity (kw) = 0.0
# gas nameplate capacity (kw) = 345000.0
